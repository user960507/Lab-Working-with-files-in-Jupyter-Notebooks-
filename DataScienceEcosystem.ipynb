# %% [markdown]
# <H1>Data Science Tools and Ecosystem

# %% [markdown]
# <H2>AUTHOR: HERE WILL BE MY NAME (NOT INCLUDED BECAUSE WE ARE USING A PU</H2>

# %% [markdown]
# ![2-title.png](attachment:5df1c008-8f2a-4e11-b7c3-548ceb0538a9.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Objectives:
# <li>Langs</li>
# <li>Libs</li>
# <li>Tools</li>

# %% [markdown]
# ![3-intro.png](attachment:857b2d27-6970-4a12-b4a4-2ac52abe6b6c.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# <li> python
# <li> R
# <li>Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# <li>Pandas</li>
# <li>scikit-learn</li>
# <li>Tensorflow</li>

# %% [markdown]
# Data Science Tools
# <li>A</li>

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
#  This a simple arithmetic expression to mutiply then add integers

# %%
minutes = 200
hours = int(200/60)
rest_mins = 200%60
print("{} minutes are equal to {}h :{}mins".format(minutes, hours, rest_mins))
# Out:
# 200 minutes are equal to 3h :20mins

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60
